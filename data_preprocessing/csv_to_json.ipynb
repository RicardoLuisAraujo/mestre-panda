# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../panda_exercises_math.csv',sep=";")

# %%
df.head()
# Out:
#    ID  year   category            sub_category  \
# 0   1    10  Geometria  Pontos, retas e planos
# 1   2    10  Geometria  Pontos, retas e planos
# 2   3    10  Geometria  Pontos, retas e planos
# 3   4    10  Geometria  Pontos, retas e planos
# 4   5    10  Geometria  Pontos, retas e planos
#
#                                            statement image  multiple_choice  \
# 0  Na figura ao lado, está representada, num refe...   q_1             True
# 1  Na figura ao lado, está representado, num refe...   q_2            False
# 2  Considere, num referencial o.n. xOy, os pontos...   NaN             True
# 3  Na figura ao lado, está representado, num refe...   q_4             True
# 4  Considere, num referencial o.n. xOy :\n• a ret...   q_5            False
#
#     option_1   option_2     option_3   option_4 true_answer  \
# 0  (-1/2, 2)    (-1, 2)  (-1/4, 1/2)    (-2, 4)      (-1,2)
# 1        NaN        NaN          NaN        NaN           6
# 2  y = -1/3x   y = 1/3x       y = 3x   y = -33x    y = 1/3x
# 3  (1, 1, 2)  (1, 2, 0)    (0, 1, 1)  (1, 1, 1)     (1,2,0)
# 4        NaN        NaN          NaN        NaN   y = 2x -2
#
#                                           resolution image_resolution  \
# 0  Como o ponto B pertence ao semieixo positivo O...              NaN
# 1  Como os pontos A, B e C têm abcissa 1, todos p...            q_2_r
# 2  O declive da reta AB é dado por:\n𝑚𝐴𝐵=  (𝑦𝐵 −𝑦...              NaN
# 3  Representando os quatro pontos, podemos verifi...            q_4_r
# 4  Como a reta deve ser paralela à reta r deve te...              NaN
#
#                                   source  Unnamed: 15
# 0                  Exame - 2019, 2ª fase          NaN
# 1           Exame - 2017, Época especial          NaN
# 2           Exame - 2016, Época especial          NaN
# 3  Teste Intermédio 10º ano - 16.03.2012          NaN
# 4  Teste Intermédio 10º ano - 16.03.2012          NaN

# %%
exercises_df = df[['ID', 'year', 'category', 'sub_category', 'statement', 'image', 'multiple_choice', 'resolution', 'image_resolution', 'source']]

# %%
exercises_df[exercises_df.columns[1:]].head()
# Out:
#    year   category            sub_category  \
# 0    10  Geometria  Pontos, retas e planos
# 1    10  Geometria  Pontos, retas e planos
# 2    10  Geometria  Pontos, retas e planos
# 3    10  Geometria  Pontos, retas e planos
# 4    10  Geometria  Pontos, retas e planos
#
#                                            statement image  multiple_choice  \
# 0  Na figura ao lado, está representada, num refe...   q_1             True
# 1  Na figura ao lado, está representado, num refe...   q_2            False
# 2  Considere, num referencial o.n. xOy, os pontos...   NaN             True
# 3  Na figura ao lado, está representado, num refe...   q_4             True
# 4  Considere, num referencial o.n. xOy :\n• a ret...   q_5            False
#
#                                           resolution image_resolution  \
# 0  Como o ponto B pertence ao semieixo positivo O...              NaN
# 1  Como os pontos A, B e C têm abcissa 1, todos p...            q_2_r
# 2  O declive da reta AB é dado por:\n𝑚𝐴𝐵=  (𝑦𝐵 −𝑦...              NaN
# 3  Representando os quatro pontos, podemos verifi...            q_4_r
# 4  Como a reta deve ser paralela à reta r deve te...              NaN
#
#                                   source
# 0                  Exame - 2019, 2ª fase
# 1           Exame - 2017, Época especial
# 2           Exame - 2016, Época especial
# 3  Teste Intermédio 10º ano - 16.03.2012
# 4  Teste Intermédio 10º ano - 16.03.2012

# %%
exercises_df[exercises_df.columns[1:]].to_json('exercises.json', orient='records')

# %%
pd.read_json('exercises.json',  orient = "records")
# Out:
#     ID  year   category            sub_category  \
# 0    1    10  Geometria  Pontos, retas e planos
# 1    2    10  Geometria  Pontos, retas e planos
# 2    3    10  Geometria  Pontos, retas e planos
# 3    4    10  Geometria  Pontos, retas e planos
# 4    5    10  Geometria  Pontos, retas e planos
# 5    6    10  Geometria  Pontos, retas e planos
# 6    7    10  Geometria  Pontos, retas e planos
# 7    8    10  Geometria  Pontos, retas e planos
# 8    9    10  Geometria  Pontos, retas e planos
# 9   10    10  Geometria  Pontos, retas e planos
# 10  11    10  Geometria  Pontos, retas e planos
#
#                                             statement image  multiple_choice  \
# 0   Na figura ao lado, está representada, num refe...   q_1             True
# 1   Na figura ao lado, está representado, num refe...   q_2            False
# 2   Considere, num referencial o.n. xOy, os pontos...  None             True
# 3   Na figura ao lado, está representado, num refe...   q_4             True
# 4   Considere, num referencial o.n. xOy :\n• a ret...   q_5            False
# 5   Na figura ao lado, está representado, em refer...   q_6            False
# 6   Na figura ao lado, está representado, em refer...   q_7            False
# 7   Considere, num referencial o.n. xOy, a reta r ...  None             True
# 8   Na figura ao lado, estão representados, num re...   q_9            False
# 9   Na figura ao lado, está representada, num refe...  q_10             True
# 10  Na figura ao lado, estão representados, num re...  q_11            False
#
#                                            resolution image_resolution  \
# 0   Como o ponto B pertence ao semieixo positivo O...             None
# 1   Como os pontos A, B e C têm abcissa 1, todos p...            q_2_r
# 2   O declive da reta AB é dado por:\n𝑚𝐴𝐵=  (𝑦𝐵 −𝑦...             None
# 3   Representando os quatro pontos, podemos verifi...            q_4_r
# 4   Como a reta deve ser paralela à reta r deve te...             None
# 5   Como a reta deve ser paralela ao eixo Oy pode ...            q_6_r
# 6   Como a reta QN é paralela ao eixo Ox, e como s...             None
# 7   Como a reta r que interseta o eixo Oy no ponto...             None
# 8   Como a base da pirâmide, [OPQR], é um quadrado...             None
# 9   Como a reta r que interseta o eixo Oy no ponto...             None
# 10                                               None             None
#
#                                    source
# 0                   Exame - 2019, 2ª fase
# 1            Exame - 2017, Época especial
# 2            Exame - 2016, Época especial
# 3   Teste Intermédio 10º ano - 16.03.2012
# 4   Teste Intermédio 10º ano - 16.03.2012
# 5   Teste Intermédio 10º ano - 06.05.2011
# 6   Teste Intermédio 11º ano - 27.01.2011
# 7   Teste Intermédio 10º ano - 05.05.2010
# 8   Teste Intermédio 10º ano - 05.05.2010
# 9   Teste Intermédio 10º ano - 29.01.2010
# 10  Teste Intermédio 10º ano - 29.01.2010

# %% [markdown]
# # Answers

# %%
answers_df = pd.melt(df, id_vars=['ID', 'true_answer'], value_vars=['option_1', 'option_2', 'option_3', 'option_4'], var_name='answer_option', value_name='answer')
answers_df.rename(columns={'ID': 'exercise_id', 'true_answer': 'real_answer'}, inplace=True)

answers_df.head()
# Out:
#    exercise_id real_answer answer_option     answer
# 0            1      (-1,2)      option_1  (-1/2, 2)
# 1            2           6      option_1        NaN
# 2            3    y = 1/3x      option_1  y = -1/3x
# 3            4     (1,2,0)      option_1  (1, 1, 2)
# 4            5   y = 2x -2      option_1        NaN

# %%
answers_df.sort_values(by=['exercise_id'], inplace=True)
answers_df.reset_index(drop=True, inplace=True)
answers_df['real_answer'] = answers_df['real_answer'].str.replace(',', ', ')
answers_df.head(10)
# Out:
#    exercise_id real_answer answer_option       answer  true_answer
# 0            1     (-1, 2)      option_1    (-1/2, 2)        False
# 1            1     (-1, 2)      option_3  (-1/4, 1/2)        False
# 2            1     (-1, 2)      option_2      (-1, 2)        False
# 3            1     (-1, 2)      option_4      (-2, 4)        False
# 4            2           6      option_3          NaN        False
# 5            2           6      option_4          NaN        False
# 6            2           6      option_2          NaN        False
# 7            2           6      option_1          NaN        False
# 8            3    y = 1/3x      option_2     y = 1/3x         True
# 9            3    y = 1/3x      option_1    y = -1/3x        False

# %%
answers_df['true_answer'] = np.where((answers_df['real_answer'] == answers_df['answer']), True, False)

# %%
answers_df.head()
# Out:
#    exercise_id real_answer answer_option       answer  true_answer
# 0            1     (-1, 2)      option_1    (-1/2, 2)        False
# 1            1     (-1, 2)      option_3  (-1/4, 1/2)        False
# 2            1     (-1, 2)      option_2      (-1, 2)         True
# 3            1     (-1, 2)      option_4      (-2, 4)        False
# 4            2           6      option_3          NaN        False

# %%
answers_df.dropna().head()
# Out:
#     exercise_id true_answer answer_option       answer
# 0             1      (-1,2)      option_1    (-1/2, 2)
# 22            1      (-1,2)      option_3  (-1/4, 1/2)
# 11            1      (-1,2)      option_2      (-1, 2)
# 33            1      (-1,2)      option_4      (-2, 4)
# 35            3    y = 1/3x      option_4     y = -33x

# %%
answers_df[['exercise_id', 'true_answer', 'answer']].dropna().to_json('answers.json', orient='records')
